# %% [markdown]
# <a href="https://colab.research.google.com/github/YuvrajMimrotZaki/SoCE-Project-ML/blob/main/Project_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/crack_detection.csv")
df.head()

# %%
df.shape

# %% [markdown]
# # New Section

# %%
X=df.iloc[:,:-1]

# %%
X
# Out:
#      Unnamed: 0    mean_r      std_r     kur_r    skew_r    mean_g      std_g  \
# 0             0  107.5734  29.267480  0.744029  0.408828  110.2533  26.953218
# 1             1  178.6713  14.917756  3.192406  0.238175  184.4947  14.882156
# 2             2  176.6517  34.618255 -0.146336 -0.421552  161.3083  33.688699
# 3             3  113.5760  20.084502  0.719752  0.737728  114.0056  19.536222
# 4             4  125.3565  29.251595  0.430344  0.833496  129.5277  28.661968
# ..          ...       ...        ...       ...       ...       ...        ...
# 695         695  147.4849  39.849040 -0.413560 -0.713162  143.8830  36.109081
# 696         696  131.6387  22.462007  0.060316 -0.598803  129.3470  20.965238
# 697         697  124.9098  24.410827 -0.014904  0.298252  130.4604  23.675959
# 698         698  100.5366  41.107908 -0.385692  0.309762   98.8532  40.835684
# 699         699  138.0759   6.627016  2.339072  0.414758  137.9345   6.328697
#
# ...

# %%
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.8)

# %%
X_train
# Out:
#      Unnamed: 0    mean_r      std_r     kur_r    skew_r    mean_g      std_g  \
# 533         533  143.3211  28.515087  0.551615  0.847747  143.4285  27.193089
# 304         304  123.5556  38.287070 -0.620635  0.178834  121.5828  38.468636
# 125         125  177.5634  13.422063  8.172005 -0.929950  183.0746  13.470324
# 539         539  126.1002  27.623942 -0.244209  0.202483  124.6038  25.598274
# 222         222  141.7421  24.037329 -0.582513  0.061808  141.3309  23.277771
# ..          ...       ...        ...       ...       ...       ...        ...
# 509         509  137.8782  20.149083  1.679971 -1.109947  135.3219  19.033762
# 691         691   99.6030  37.177800 -0.390908  0.192256   98.2543  37.293568
# 52           52  109.2267  21.581365  0.528685 -0.855854  105.1634  21.413876
# 504         504  125.9069  17.060329  0.705690  0.010344  125.0863  16.024976
# 693         693  119.0244  35.731317 -0.224814  0.588689  118.9234  34.931300
#
# ...

# %%
X_train_new, X_val, y_train_new, y_val = train_test_split(X_train,y_train,train_size=0.75)

# %%
X_train_new.shape,X_val.shape,X_test
# Out:
# ((420, 24),
#  (140, 24),
#       Unnamed: 0    mean_r      std_r     kur_r    skew_r    mean_g      std_g  \
#  296         296  127.6075  34.796518 -0.857849  0.198542  128.0345  30.564367
#  498         498  126.6920  23.807241  0.281122 -0.630267  125.7512  22.360297
#  670         670  119.3934  18.292294  1.166147  0.384498  120.5814  18.608728
#  54           54  157.4694  20.478263  0.780024  0.040802  155.9337  20.481326
#  349         349  134.3233  38.401299 -0.913172 -0.176999  134.3429  34.512936
#  ..          ...       ...        ...       ...       ...       ...        ...
#  11           11  133.1240  45.537644 -1.063483 -0.154351  128.5033  43.787987
#  537         537  113.0747  18.810112  0.889505  0.692702  113.6063  18.224986
#  464         464  129.3645  38.805369 -0.988484  0.228842  134.2996  36.230587
#  627         627  124.3773  25.230457  0.980902  0.624281  125.7362  23.960393
# ...

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression(solver='lbfgs', max_iter=100000)
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
y_predtest = model.predict(X_test)

# %%
y_predtrain = model.predict(X_train)

# %%
y_predval = model.predict(X_val)

# %%
model.score(X_test,y_test)
# Out:
# 0.8285714285714286

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_predtest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82        72
#            1       0.79      0.88      0.83        68
#
#     accuracy                           0.83       140
#    macro avg       0.83      0.83      0.83       140
# weighted avg       0.83      0.83      0.83       140

# %%
print(classification_report(y_train,y_predtrain))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76       279
#            1       0.76      0.81      0.78       281
#
#     accuracy                           0.77       560
#    macro avg       0.77      0.77      0.77       560
# weighted avg       0.77      0.77      0.77       560

# %%
print(classification_report(y_val,y_predval))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.68      0.71        62
#            1       0.76      0.81      0.78        78
#
#     accuracy                           0.75       140
#    macro avg       0.75      0.74      0.74       140
# weighted avg       0.75      0.75      0.75       140
